# %%
#1 - Akansh - Write a Python function to find the maximum of three numbers.
def max_of_three(a, b, c):
    return max(a, b, c)
print(max_of_three(2, 7, -3))
# Out:
# 7

# %%
#task 1 Hajrah's code
def max(number1, number2, number3):
  if (number1>number2) and (number1>number3):
    print ("Maximum number is " + str(number1))
  elif (number2>number1) and (number2>number3):
    print ("Maximum number is " + str(number2))
  elif (number3>number1) and (number3>number1):
    print ("Maximum number is " + str(number3))

number1 = int(input("Enter your first number: "))
number2 = int(input("Enter your second number: "))
number3 = int(input("Enter your third number: "))

print(max(number1, number2, number3))

# %%
#2 - Akansh's Write a Python function to sum all the numbers in a list.
def sum(a, b, c, d, e):
  return(a + b + c + d + e)

print(sum(8, 2, 3, 0, 7))

# %%
#task 2 - Hajrah's version
def sum(number1, number2, number3, number4, number5):
  print(number1 + number2 + number3 + number4 + number5)

number1 = 8
number2 = 2
number3 = 3
number4 = 0
number5 = 7

print(sum(number1, number2, number3, number4, number5))

# %%
#3 - Akansh's Write a Python function to multiply all the numbers in a list.
def multiply(a, b, c, d, e):
  return(a * b * c * d * e)

multiply(8, 2, 3, -1, 7)
# Out:
# -336

# %%
#task 3 - Hajrah's version
def sum(number1, number2, number3, number4, number5):
  print(number1 * number2 * number3 * number4 * number5)

number1 = 8
number2 = 2
number3 = 3
number4 = -1
number5 = 7

print(sum(number1, number2, number3, number4, number5))

# %%
#4 - Akansh Write a Python program to reverse a string.
txt = "lynnrose"[::-1]
print(txt)
# Out:
# esornnyl

# %%
#task 4 - Hajrah's version
#https://www.w3schools.com/python/python_howto_reverse_string.asp

def reverse(text):
  lol = text[::-1]
  print(lol)

text = "1234abcd"

print(reverse(text))
# Out:
# dcba4321
# None

# %%
#5 - Akansh Write a Python function to calculate the factorial of a number (a non-negative integer). The function accepts the number as an argument.
def factorial(x):
  if x == 0:
    return 1
  else:
    return x * factorial(x-1)
x = int(input("give me the factorial: "))
print(factorial(x))
# Out:
# give me the factorial: 5
# 120

# %%
#task 5 - Hajrah's version
#Factorial equation https://www.google.com/search?q=factorial+equation&rlz=1C5CHFA_enCA966CA966&oq=factorial+equa&gs_lcrp=EgZjaHJvbWUqBwgAEAAYgAQyBwgAEAAYgAQyBwgBEAAYgAQyBggCEAYYQDIGCAMQRRg5MgcIBBAAGIAEMgcIBRAAGIAEMgcIBhAAGIAEMgcIBxAAGIAEMgcICBAAGIAEMgcICRAAGIAEqAIAsAIA&sourceid=chrome&ie=UTF-8&safe=active&ssui=on

def stuff(factorial):
  calculation = ((factorial - 1)*factorial)
  print(calculation)

factorial = int(input("Enter your number to find factorial: "))
print(stuff(factorial))
# Out:
# Enter your number to find factorial: 5
# 20
# None

# %%
#5 Dysan Griffin
x = int(input("Put number here, NOW "))
y = ((x - 1) * (x - 2) * )
print(y)
# Out:
#   File "<ipython-input-7-00418a6b739d>", line 3
#     y = ((x - 1) * (x - 2) * )
#                              ^
# SyntaxError: invalid syntax
