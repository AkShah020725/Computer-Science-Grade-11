# %%
#int addition
variable1 = int(input("type a number"))
variable2 = int(input("type another one"))

add = variable1+variable2
print (add)
# Out:
# type a number2
# type another one4
# 6

# %%
#float additon
variable1 = float(input("type a number"))
variable2 = float(input("type another one"))

add = variable1+variable2
print (add)
# Out:
# type a number2.2
# type another one4.2
# 6.4

# %%
#int subtraction
variable1 = int(input("type a number"))
variable2 = int(input("type another one"))

subtract = variable1-variable2
print (subtract)
# Out:
# type a number2
# type another one1
# 1

# %%
#float subtraction
variable1 = float(input("type a number"))
variable2 = float(input("type another number"))

subtract = variable1-variable2
print (subtract)
# Out:
# type a number2.5
# type another number2.2
# 0.2999999999999998

# %%
#int multiply
variable1 = int(input("type a number"))
variable2 = int(input("type another number"))

multiply = variable1 * variable2
print (multiply)
# Out:
# type a number5
# type another number7
# 35

# %%
#float multiply
variable1 = float(input("type a number"))
variable2 = float(input("type another number"))

multiply = variable1 * variable2
print (multiply)
# Out:
# type a number5.4
# type another number2.3
# 12.42

# %%
#int divide
variable1 = int(input("type a number"))
variable2 = int(input("type another number"))

divide = variable1 / variable2
print (divide)
# Out:
# type a number25
# type another number5
# 5.0

# %%
#float divide
variable1 = float(input("type a number"))
variable2 = float(input("type another number"))

divide = variable1 / variable2
print (divide)
# Out:
# type a number2.6
# type another number1.4
# 1.8571428571428574

# %%
add = 23+4
degree = add + 230 * 3
output = (degree/add)
print (output)
# Out:
# 26.555555555555557

# %%
pi = 22/7
degree = float(input("Input degrees: "))
radian = pi * (degree/180)
print (radian)
# Out:
# Input degrees: 180
# 3.142857142857143

# %%
name = input("What is your name?")
age = int(input("What is your age?"))
newage = age-10
print (name, "your age is", age, "and 10 years back you were", newage)
# Out:
# What is your name?Akansh
# What is your age?17
# Akansh your age is 17 and 10 years back you were 7

# %%
a = int(input("enter the first number"))
b = int(input("enter the second number"))

if a>b:
  print ("first number is larger")

if b>a:
  print ("second number is larger")
# Out:
# enter the first number7
# enter the second number2
# first number is larger

# %%
#int triangle area
b = int(input("type the base number"))
h = int(input("type height the number"))

area = 1/2 * b * h
print (area)
# Out:
# type the base number2
# type height the number4
# 4.0

# %%
#float triangle area
b = float(input("type the base number"))
h = float(input("type the height number"))

area = 1/2 * b * h
print (area)
# Out:
# type the base number2.6
# type the height number4.3
# 5.59

# %%
#int sqaure area
a = int(input("type the number of one side"))
a = int(input("type the number of another"))

area = a * a
print (area)
# Out:
# type the number of one side5
# type the number of another5
# 25

# %%
#float square area
a = float(input("type the number of one side"))
a = float(input("type the number of another"))

area = a * a
print (area)
# Out:
# type the number of one side2.4
# type the number of another2.4
# 5.76

# %%
#int rectangle area
l = int(input("type the length"))
w = int(input("type the width"))

area = l * w
print (area)
# Out:
# type the length6
# type the width4
# 24

# %%
#float rectangle area
l = float(input("type the length"))
w = float(input("type the width"))

area = l * w
print (area)
# Out:
# type the length2.7
# type the width3.9
# 10.530000000000001

# %%
#int circle area
pi = 22/7
d = int(input("type the diameter"))
r = int(input("type the radius"))

area = pi * (d/2)**2
print (area)
# Out:
# type the diameter8
# type the radius4
# 50.285714285714285

# %%
#float circle area
pi = 22/7
d = float(input("type the diameter"))
r = float(input("type the radius"))

area = pi * (d/2)**2
print (area)
# Out:
# type the diameter4.6
# type the radius2.3
# 16.62571428571428

# %%
#int sphere area
pi = 22/7
d = int(input("type the diameter"))
r = int(input("type the radius"))

volume = (4/3 * pi * r**3)
print (volume)
# Out:
# type the diameter12
# type the radius6
# 905.142857142857

# %%
8%2
# Out:
# 0

# %%
7/3
# Out:
# 2.3333333333333335

# %%
19%2
# Out:
# 1

# %%
a=3
if a == 3:
  print ("the variable had the value 3")
elif a!=3:
  print("the variable does not have the value 3")
# Out:
# the variable had the value 3

# %%
age = int(input("what is your age"))
if age > 17:
  print("can see a rated R movie")
elif age < 17 and age > 12:
  print("can see a rated pg-13 movie")
else:
  print("can only see rated pg movies")
# Out:
# what is your age18
# can see a rated R movie

# %%
a = int(input("type a number"))
b = a % 2

if b > 0:
  print ("the number is odd")
else:
  print ("the number is even")
# Out:
# type a number6246
# the number is even

# %%
number = int(input("give me a number"))
check = int(input("give me another number"))
if number%4 == 0:
  print ("number divides evenly into check")
else:
  print ("number doesn't divide into check")
# Out:
# give me a number8
# give me another number4
# number divides evenly into check

# %%
grade = int(input("give me a grade: "))
if grade >= 90:
  print ("A")
elif grade >= 80:
  print ("B")
elif grade >= 70:
  print ("C")
elif grade >= 65:
  print ("D")
else:
  print ("F")
# Out:
# give me a grade: 90
# A

# %%
number1 = int(input("give me a number"))
number2 = int(input("give me another number"))
if number1 >= number2:
  if number1 == number2:
    print (number1, "and", number2, "are equal")
  else:
      print (number1, "is greater than", number2)
else:
        print (number1, "is smaller than", number2)
# Out:
# give me a number6
# give me another number3
# 6 is greater than 3

# %%
#multiplaction table from (1-10)
table = int(input("which multiplacation table do you want: "))
print (table, "x", "1 =", table*1)
print (table, "x", "2 =", table*2)
print (table, "x", "3 =", table*3)
print (table, "x", "4 =", table*4)
print (table, "x", "5 =", table*5)
print (table, "x", "6 =", table*6)
print (table, "x", "7 =", table*7)
print (table, "x", "8 =", table*8)
print (table, "x", "9 =", table*9)
print (table, "x", "10 =", table*10)
# Out:
# which multiplacation table do you want: 8
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80

# %%
#area of triangle
b = int(input("what is the base"))
h = int(input("what is the height"))
area = b * h / 2
print (area)
# Out:
# what is the base8
# what is the height4
# 16.0

# %%
#area of sqaure
a = int(input("give me a nunber"))
b = int(input("give me another number"))
area = a * a
print (area)
# Out:
# give me a nunber6
# give me another number6
# 36

# %%
grade = int(input("give me a grade: "))
if grade >= 90:
  print ("A")
elif grade >= 80:
  print ("B")
elif grade >= 70:
  print ("C")
elif grade >= 65:
  print ("D")
else:
  print ("F")
# Out:
# give me a grade: 78
# C

# %%
#1 - Akansh - Write a Python function to find the maximum of three numbers.
def max_of_three(a, b, c):
    return max(a, b, c)
print(max_of_three(2, 7, -3))
# Out:
# 7

# %%
#2 - Akansh's Write a Python function to sum all the numbers in a list.
def sum(a, b, c, d, e):
  return(a + b + c + d + e)

print(sum(8, 2, 3, 0, 7))
# Out:
# 20

# %%
#3 - Akansh's Write a Python function to multiply all the numbers in a list.
def multiply(a, b, c, d, e):
  return(a * b * c * d * e)

multiply(8, 2, 3, -1, 7)
# Out:
# -336

# %%
#4 - Akansh Write a Python program to reverse a string.
txt = "lynnrose"[::-1]
print(txt)
# Out:
# esornnyl

# %%
#5 - Akansh Write a Python function to calculate the factorial of a number (a non-negative integer). The function accepts the number as an argument.
def factorial(x):
  if x == 0:
    return 1
  else:
    return x * factorial(x-1)
x = int(input("give me the factorial: "))
print(factorial(x))
# Out:
# give me the factorial: 5
# 120

# %%
def greet(first_name, last_name):
    print (f"Hello  {first_name} {last_name}")
    print ("welcome to Canada")
greet("Akansh", "Shah")
greet("Virat", "Kohli")
# Out:
# Hello  Akansh Shah
# welcome to Canada
# Hello  Virat Kohli
# welcome to Canada

# %%
def get_money(name):
  print(f"Hi {name}")
  return f"Hi {name}"

# %%
def increment(number, by):
  return number + by
print(increment(2, by=5))
# Out:
# 7

# %%
def multiply(*numbers):
  total = 1
  for number in numbers:
    total *= number
  return total

print(multiply(2, 3, 4, 5))
# Out:
# 120

# %%
def save_user(**user):
  print(user["name"])
save_user(id=1, name="bob", age=19)
# Out:
# bob

# %%
message = "y"
def welcome(name):
  message = "x"
  welcome("Akansh")
print (message)
# Out:
# y

# %%
def Right_Wrong(input):
  if input % 3 == 0:
      return "Right"
  if input % 5 == 0:
      return "Wrong"
  if (input % 3 == 0) and (input % 5 == 0):
      return "RightWrong"
      return input
print(Right_Wrong(40))
# Out:
# Wrong

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
  if x == "banana":
    break
# Out:
# apple
# banana

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    break
  print(x)
# Out:
# apple

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    continue
  print(x)
# Out:
# apple
# cherry

# %%
for x in range(6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#2 is inclusive & 6 is exclusive
for x in range(2, 6):
  print(x)
# Out:
# 2
# 3
# 4
# 5

# %%
for x in range(2, 30, 3):
  print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29

# %%
for x in range(6):
  if x == 3: break
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2

# %%
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]

for x in adj:
  for y in fruits:
    print(x, y)
# Out:
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry

# %%
i = 1
while i < 6:
  print(i)
  i += 2
# Out:
# 1
# 3
# 5

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6
