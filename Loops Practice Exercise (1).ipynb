# %%
# Task 1
number = 75869
count = 0
while number != 0:
  number = number // 10
  count = count + 1
print("Total number of digits is =", count)
# Out:
# Total number of digits is = 5

# %%
# Task 2
rows = int(input("Enter number of rows: "))
for x in range(5, 0, -1):
    for y in range(x, 0, -1):
        print(y, end=" ")
    print()
# Out:
# Enter number of rows: 5
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1

# %%
# Task 3
numbers = (10, 20, 30, 40, 50)
reverse_numbers = numbers[::-1]

for number in reverse_numbers:
    print(number)
# Out:
# 50
# 40
# 30
# 20
# 10

# %%
# Task 4
min = int(input("Give me the min value: "))
max = int(input("Give me the max value: "))

for num in range(min, max + 1):
  if num > 1:
    for i in range(2,num):
      if num%i == 0:
        break
    else:
      print(num)
# Out:
# Give me the min value: 2
# Give me the max value: 50
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-d185d90d19af> in <cell line: 5>()
#       3 max = int(input("Give me the max value: "))
#       4
# ----> 5 for num in range(min, max + 1):
#       6   if num > 1:
#       7     for i in range(2,num):
#
# TypeError: 'tuple' object is not callable
