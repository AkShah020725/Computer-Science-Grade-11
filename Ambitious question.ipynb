# %%
#From the dataset called data.csv, draw a line graph and a bar graph too using the Duration-Pulse and Duration-Calories axis.
# Out:
#   File "<ipython-input-1-eb79c9be6abf>", line 1
#     From the dataset called data.csv, draw a line graph and a bar graph too using the Duration-Pulse and Duration-Calories axis.
#          ^
# SyntaxError: invalid syntax
