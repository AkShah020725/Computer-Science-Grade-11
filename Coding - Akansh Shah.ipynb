# %%
name = "Akansh"
hobby = "badminton"

print (name + " loves to play " + " " + hobby)
# Out:
# Akansh loves to play  badminton

# %%
x = "Akansh"
y = "John Wick"

print (x + "'s favourite movie is " + y)
print (x + " watched it 100 times ")
# Out:
# Akansh's favourite movie is John Wick
# Akansh watched it 100 times

# %%
if 5 > 2:
  print ("yes")

else:
  ("this is wrong")
# Out:
# yes

# %%
name = "Akansh Shah"
age = "17"
print(name + " is " + age + " years old ")
# Out:
# Akansh Shah is 17 years old

# %%
x = 4
print(x)
# Out:
# 4

# %%
x = 8
y = 2
print (x+y)
print (x-y)
print (x/y)
print (x*y)
# Out:
# 10
# 6
# 4.0
# 16

# %%
variable1 = input ("whats your name?")
print (variable1)
# Out:
# whats your name?Akansh
# Akansh

# %%
variable1 = float(input ("give me a number"))
print (variable1)

variable2 = float(input ("give me another number"))
print (variable2)
print (variable1+variable2)
# Out:
# give me a number1.2
# 1.2
# give me another number2.2
# 2.2
# 3.4000000000000004

# %%
variable1 = int(input("give me a number"))
variable2 = int(input(("give me a number")))
add = variable1 + variable2
print (add)
# Out:
# give me a number4
# give me a number7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-5c47526f497b> in <cell line: 4>()
#       2 variable2 = int(input(("give me a number")))
#       3 add = variable1 + variable2
# ----> 4 print (add)
#
# TypeError: 'int' object is not callable

# %%
variable1 = int(input("type anumber"))
variable2 = int(input("type another one"))

add = variable1+variable2
print (add)
# Out:
# type anumber2
# type another one4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-3d7b2c762c1d> in <cell line: 5>()
#       3
#       4 add = variable1+variable2
# ----> 5 print (add)
#
# TypeError: 'int' object is not callable
